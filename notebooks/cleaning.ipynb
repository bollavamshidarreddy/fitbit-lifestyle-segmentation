# %%
# Add src folder to Python path so db_config can be imported
import sys
import os

sys.path.append(os.path.abspath("../src"))

# %%
# Used to execute SQL queries and show results
from sqlalchemy import text
from db_config import engine
import pandas as pd

# %% [markdown]
# ## **checking for null values**

# %%
# Returns NULL counts as a Pandas DataFrame for clarity
def check_nulls(table_name):
    with engine.connect() as conn:
        columns = conn.execute(text("""
            SELECT column_name
            FROM information_schema.columns
            WHERE table_schema = DATABASE()
              AND table_name = :table
        """), {"table": table_name}).fetchall()

        queries = []
        for col in columns:
            queries.append(
                f"SELECT '{col[0]}' AS column_name, "
                f"SUM(CASE WHEN `{col[0]}` IS NULL THEN 1 ELSE 0 END) AS null_count "
                f"FROM `{table_name}`"
            )

        final_query = " UNION ALL ".join(queries)
        result = conn.execute(text(final_query)).fetchall()

    return pd.DataFrame(result, columns=["column_name", "null_count"])

# %%
# NULL counts for daily_activity
check_nulls("dailyactivity_merged")
# Out:
#                  column_name null_count
# 0               ActivityDate          0
# 1                   Calories          0
# 2        FairlyActiveMinutes          0
# 3                         Id          0
# 4        LightActiveDistance          0
# 5       LightlyActiveMinutes          0
# 6   LoggedActivitiesDistance          0
# 7   ModeratelyActiveDistance          0
# 8    SedentaryActiveDistance          0
# 9           SedentaryMinutes          0
# 10             TotalDistance          0
# 11                TotalSteps          0
# 12           TrackerDistance          0
# 13        VeryActiveDistance          0
# 14         VeryActiveMinutes          0

# %%
check_nulls("dailycalories_merged")
# Out:
#    column_name null_count
# 0  ActivityDay          0
# 1     Calories          0
# 2           Id          0

# %%
check_nulls("dailyintensities_merged")
# Out:
#                 column_name null_count
# 0               ActivityDay          0
# 1       FairlyActiveMinutes          0
# 2                        Id          0
# 3       LightActiveDistance          0
# 4      LightlyActiveMinutes          0
# 5  ModeratelyActiveDistance          0
# 6   SedentaryActiveDistance          0
# 7          SedentaryMinutes          0
# 8        VeryActiveDistance          0
# 9         VeryActiveMinutes          0

# %%
check_nulls("dailysteps_merged")
# Out:
#    column_name null_count
# 0  ActivityDay          0
# 1           Id          0
# 2    StepTotal          0

# %%
check_nulls("heartrate_seconds_merged")
# Out:
#   column_name null_count
# 0          Id          0
# 1        Time          0
# 2       Value          0

# %%
check_nulls('hourlycalories_merged')
# Out:
#     column_name null_count
# 0  ActivityHour          0
# 1      Calories          0
# 2            Id          0

# %%
check_nulls('hourlyintensities_merged')
# Out:
#         column_name null_count
# 0      ActivityHour          0
# 1  AverageIntensity          0
# 2                Id          0
# 3    TotalIntensity          0

# %%
check_nulls('hourlysteps_merged')
# Out:
#     column_name null_count
# 0  ActivityHour          0
# 1            Id          0
# 2     StepTotal          0

# %%
check_nulls('minuteCaloriesNarrow_merged')
# Out:
#       column_name null_count
# 0  ActivityMinute          0
# 1        Calories          0
# 2              Id          0

# %%
check_nulls('minuteCaloriesWide_merged')
# Out:
#      column_name null_count
# 0   ActivityHour          0
# 1     Calories00          0
# 2     Calories01          0
# 3     Calories02          0
# 4     Calories03          0
# ..           ...        ...
# 57    Calories56          0
# 58    Calories57          0
# 59    Calories58          0
# 60    Calories59          0
# 61            Id          0
#
# [62 rows x 2 columns]

# %%
check_nulls('minuteIntensitiesNarrow_merged')
# Out:
#       column_name null_count
# 0  ActivityMinute          0
# 1              Id          0
# 2       Intensity          0

# %%
check_nulls('minuteIntensitiesWide_merged')
# Out:
#      column_name null_count
# 0   ActivityHour          0
# 1             Id          0
# 2    Intensity00          0
# 3    Intensity01          0
# 4    Intensity02          0
# ..           ...        ...
# 57   Intensity55          0
# 58   Intensity56          0
# 59   Intensity57          0
# 60   Intensity58          0
# 61   Intensity59          0
#
# [62 rows x 2 columns]

# %%
check_nulls('minuteMETsNarrow_merged')
# Out:
#       column_name null_count
# 0  ActivityMinute          0
# 1              Id          0
# 2            METs          0

# %%
check_nulls('minutesleep_merged')
# Out:
#   column_name null_count
# 0        date          0
# 1          Id          0
# 2       logId          0
# 3       value          0

# %%
check_nulls('minuteStepsNarrow_merged')
# Out:
#       column_name null_count
# 0  ActivityMinute          0
# 1              Id          0
# 2           Steps          0

# %%
check_nulls('minuteStepsWide_merged')
# Out:
#      column_name null_count
# 0   ActivityHour          0
# 1             Id          0
# 2        Steps00          0
# 3        Steps01          0
# 4        Steps02          0
# ..           ...        ...
# 57       Steps55          0
# 58       Steps56          0
# 59       Steps57          0
# 60       Steps58          0
# 61       Steps59          0
#
# [62 rows x 2 columns]

# %%
check_nulls('sleepday_merged')
# Out:
#           column_name null_count
# 0                  Id          0
# 1            SleepDay          0
# 2  TotalMinutesAsleep          0
# 3   TotalSleepRecords          0
# 4      TotalTimeInBed          0

# %%
check_nulls('weightloginfo_merged')
# Out:
#       column_name null_count
# 0             BMI          0
# 1            Date          0
# 2             Fat         65
# 3              Id          0
# 4  IsManualReport          0
# 5           LogId          0
# 6        WeightKg          0
# 7    WeightPounds          0

# %% [markdown]
# ## RESULT
# >* NULL profiling shows that all minute-level activity and sleep tables contain complete data with no missing values.
# >* Missing values are present only in the `weightloginfo_merged` table, specifically in the `Fat` column.

# %%
# Replace NULL fat percentage with 0
with engine.connect() as conn:
    conn.execute(text("""
        UPDATE weightloginfo_merged
        SET Fat = 0
        WHERE Fat IS NULL;
    """))
    conn.commit()

# %%
check_nulls('weightloginfo_merged')
# Out:
#       column_name null_count
# 0             BMI          0
# 1            Date          0
# 2             Fat          0
# 3              Id          0
# 4  IsManualReport          0
# 5           LogId          0
# 6        WeightKg          0
# 7    WeightPounds          0

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## **Duplicate Value Checking**
#
# >* Duplicate checks are performed on logical primary keys such as Id + Date/Time combinations to identify repeated records.

# %%
# Check duplicate daily activity records per user per date
with engine.connect() as conn:
    conn.execute(text("""
        SELECT Id, ActivityDate, COUNT(*) AS duplicate_count
        FROM dailyactivity_merged
        GROUP BY Id, ActivityDate
        HAVING COUNT(*) > 1;
    """)).fetchall()

# %%
# Check duplicate sleep records per user per day
with engine.connect() as conn:
    conn.execute(text("""
        SELECT Id, SleepDay, COUNT(*) AS duplicate_count
        FROM sleepday_merged
        GROUP BY Id, SleepDay
        HAVING COUNT(*) > 1;
    """)).fetchall()

# %%
# Check duplicate heart rate records per user per second
with engine.connect() as conn:
    conn.execute(text("""
        SELECT Id, Time, COUNT(*) AS duplicate_count
        FROM heartrate_seconds_merged
        GROUP BY Id, Time
        HAVING COUNT(*) > 1;
    """)).fetchall()

# %%
# Check duplicate minute-level sleep records
with engine.connect() as conn:
    conn.execute(text("""
        SELECT Id, date, COUNT(*) AS duplicate_count
        FROM minutesleep_merged
        GROUP BY Id, date
        HAVING COUNT(*) > 1;
    """)).fetchall()

# %%
# Check duplicate weight log entries
with engine.connect() as conn:
    conn.execute(text("""
        SELECT Id, Date, COUNT(*) AS duplicate_count
        FROM weightloginfo_merged
        GROUP BY Id, Date
        HAVING COUNT(*) > 1;
    """)).fetchall()

# %% [markdown]
# >* no duplicate found in above table (fact table)

# %% [markdown]
# ## **Data Type Conversion**
#
# >* After handling NULL values and duplicates, column data types were validated and standardized to ensure schema consistency.

# %%
# Check column data types for dailyactivity_merged
with engine.connect() as conn:
    result = conn.execute(text("""
        SELECT column_name, data_type
        FROM information_schema.columns
        WHERE table_schema = DATABASE()
          AND table_name = 'dailyactivity_merged'
        ORDER BY ordinal_position;
    """)).fetchall()

pd.DataFrame(result, columns=["column_name", "data_type"])
# Out:
#                  column_name data_type
# 0                         Id    bigint
# 1               ActivityDate      text
# 2                 TotalSteps    bigint
# 3              TotalDistance    double
# 4            TrackerDistance    double
# 5   LoggedActivitiesDistance    double
# 6         VeryActiveDistance    double
# 7   ModeratelyActiveDistance    double
# 8        LightActiveDistance    double
# 9    SedentaryActiveDistance    double
# 10         VeryActiveMinutes    bigint
# 11       FairlyActiveMinutes    bigint
# 12      LightlyActiveMinutes    bigint
# 13          SedentaryMinutes    bigint
# 14                  Calories    bigint

# %%
# Convert ActivityDate values from text to proper DATE format
with engine.connect() as conn:
    conn.execute(text("""
        UPDATE dailyactivity_merged
        SET ActivityDate = STR_TO_DATE(ActivityDate, '%m/%d/%Y');
    """))
    conn.commit()

# %%
# Change column type after data conversion
with engine.connect() as conn:
    conn.execute(text("""
        ALTER TABLE dailyactivity_merged
        MODIFY ActivityDate DATE;
    """))
    conn.commit()

# %%
# Validate conversion
with engine.connect() as conn:
    res=conn.execute(text("""
        SELECT ActivityDate
        FROM dailyactivity_merged
        LIMIT 5;
    """)).fetchall()
res
# Out:
# [(datetime.date(2016, 4, 12),),
#  (datetime.date(2016, 4, 13),),
#  (datetime.date(2016, 4, 14),),
#  (datetime.date(2016, 4, 15),),
#  (datetime.date(2016, 4, 16),)]

# %% [markdown]
# ---

# %%
with engine.connect() as conn:
    result = conn.execute(text("""
        SELECT column_name, data_type
        FROM information_schema.columns
        WHERE table_schema = DATABASE()
          AND table_name = 'dailycalories_merged'
        ORDER BY ordinal_position;
    """)).fetchall()

pd.DataFrame(result, columns=["column_name", "data_type"])
# Out:
#    column_name data_type
# 0           Id    bigint
# 1  ActivityDay      date
# 2     Calories    bigint

# %%
# Normalize ActivityDay values
with engine.connect() as conn:
    conn.execute(text("""
        UPDATE dailycalories_merged
        SET ActivityDay = STR_TO_DATE(ActivityDay, '%m/%d/%Y');
    """))
    conn.commit()

# %%
# Convert ActivityDay to DATE
with engine.connect() as conn:
    conn.execute(text("""
        ALTER TABLE dailycalories_merged
        MODIFY ActivityDay DATE;
    """))
    conn.commit()

# %% [markdown]
# ---

# %%
# Normalize ActivityDay values
with engine.connect() as conn:
    conn.execute(text("""
        UPDATE dailyintensities_merged
        SET ActivityDay = STR_TO_DATE(ActivityDay, '%m/%d/%Y');
    """))
    conn.commit()

# %%
# Convert ActivityDay to DATE
with engine.connect() as conn:
    conn.execute(text("""
        ALTER TABLE dailyintensities_merged
        MODIFY ActivityDay DATE;
    """))
    conn.commit()

# %% [markdown]
# ---

# %%
# Normalize ActivityDay values
with engine.connect() as conn:
    conn.execute(text("""
        UPDATE dailysteps_merged
        SET ActivityDay = STR_TO_DATE(ActivityDay, '%m/%d/%Y');
    """))
    conn.commit()

# %%
# Convert ActivityDay to DATE
with engine.connect() as conn:
    conn.execute(text("""
        ALTER TABLE dailysteps_merged
        MODIFY ActivityDay DATE;
    """))
    conn.commit()

# %% [markdown]
# ---

# %%
# Normalize SleepDay values including time and AM/PM
with engine.connect() as conn:
    conn.execute(text("""
        UPDATE sleepday_merged
        SET SleepDay = STR_TO_DATE(SleepDay, '%m/%d/%Y %h:%i:%s %p');
    """))
    conn.commit()

# %%
# Convert SleepDay to DATE
with engine.connect() as conn:
    conn.execute(text("""
        ALTER TABLE sleepday_merged
        MODIFY SleepDay DATE;
    """))
    conn.commit()

# %%
with engine.connect() as conn:
    res =conn.execute(text("""
        SELECT SleepDay
        FROM sleepday_merged
        LIMIT 5;
    """)).fetchall()
res
# Out:
# [(datetime.date(2016, 4, 12),),
#  (datetime.date(2016, 4, 13),),
#  (datetime.date(2016, 4, 15),),
#  (datetime.date(2016, 4, 16),),
#  (datetime.date(2016, 4, 17),)]

# %% [markdown]
# ---

# %%
# Normalize minutesleep date values (AM/PM format)
with engine.connect() as conn:
    conn.execute(text("""
        UPDATE minutesleep_merged
        SET date = STR_TO_DATE(date, '%m/%d/%Y %h:%i:%s %p');
    """))
    conn.commit()

# %%
# Convert date to DATETIME
with engine.connect() as conn:
    conn.execute(text("""
        ALTER TABLE minutesleep_merged
        MODIFY date DATETIME;
    """))
    conn.commit()

# %%
with engine.connect() as conn:
    res=conn.execute(text("""
        SELECT date
        FROM minutesleep_merged
        LIMIT 5;
    """)).fetchall()
res
# Out:
# [(datetime.datetime(2016, 4, 12, 2, 47, 30),),
#  (datetime.datetime(2016, 4, 12, 2, 48, 30),),
#  (datetime.datetime(2016, 4, 12, 2, 49, 30),),
#  (datetime.datetime(2016, 4, 12, 2, 50, 30),),
#  (datetime.datetime(2016, 4, 12, 2, 51, 30),)]

# %% [markdown]
# ---

# %%
# Check column data types for dailyactivity_merged
with engine.connect() as conn:
    result = conn.execute(text("""
        SELECT column_name, data_type
        FROM information_schema.columns
        WHERE table_schema = DATABASE()
          AND table_name = 'heartrate_seconds_merged'
        ORDER BY ordinal_position;
    """)).fetchall()

pd.DataFrame(result, columns=["column_name", "data_type"])
# Out:
#   column_name data_type
# 0          Id    bigint
# 1        Time      text
# 2       Value    bigint

# %%
# Normalize Time values to MySQL DATETIME format
with engine.connect() as conn:
    res=conn.execute(text("""
        select time from heartrate_seconds_merged limit 5;
    """)).fetchall()
res
# Out:
# [('4/12/2016 7:21:00 AM',),
#  ('4/12/2016 7:21:05 AM',),
#  ('4/12/2016 7:21:10 AM',),
#  ('4/12/2016 7:21:20 AM',),
#  ('4/12/2016 7:21:25 AM',)]

# %%
# Convert Time column to DATETIME
with engine.connect() as conn:
    conn.execute(text("""
        ALTER TABLE heartrate_seconds_merged
        MODIFY Time DATETIME;
    """))
    conn.commit()

# %%
with engine.connect() as conn:
    res=conn.execute(text("""
        SELECT Time
        FROM heartrate_seconds_merged
        LIMIT 5;
    """)).fetchall()
res

# %%
# Check how many rows still need conversion
with engine.connect() as conn:
    res=conn.execute(text("""
        SELECT COUNT(*) 
        FROM heartrate_seconds_merged
        WHERE Time LIKE '%/%';
    """)).fetchone()
res
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Check how many rows still need conversion
#       2 with engine.connect() as conn:
# ----> 3     res=conn.execute(text("""
#       4         SELECT COUNT(*)
#       5         FROM heartrate_seconds_merged
#       6         WHERE Time LIKE '%/%';
#       7     """)).fetchone()
#       8 res
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\sqlalchemy\sql\elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525     if TYPE_CHECKING:
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#     531     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\sqlalchemy\engine\base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\sqlalchemy\engine\base.py:2366, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2364     else:
#    2365         assert exc_info[1] is not None
# -> 2366         raise exc_info[1].with_traceback(exc_info[2])
#    2367 finally:
#    2368     del self._reentrant_error
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\pymysql\connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\pymysql\connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\pymysql\connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\pymysql\connections.py:751, in Connection._read_packet(self, packet_type)
#     749 buff = bytearray()
#     750 while True:
# --> 751     packet_header = self._read_bytes(4)
#     752     # if DEBUG: dump_packet(packet_header)
#     754     btrl, btrh, packet_number = struct.unpack("<HBB", packet_header)
#
# File c:\Users\Tarun Y\Desktop\capstone_project\fitbit-lifestyle-segmentation\env\Lib\site-packages\pymysql\connections.py:789, in Connection._read_bytes(self, num_bytes)
#     787 while True:
#     788     try:
# --> 789         data = self._rfile.read(num_bytes)
#     790         break
#     791     except OSError as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# KeyboardInterrupt:
